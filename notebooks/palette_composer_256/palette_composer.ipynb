# %%
from typing import Optional
import numpy as np
import gymnasium as gym
from gymnasium import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.logger import configure
from stable_baselines3.common.monitor import Monitor
import torch
from stable_baselines3.common.vec_env import VecNormalize, DummyVecEnv
from sympy.physics.units import velocity


# Define the RL environment
class ColorMatchEnv(gym.Env):
    def __init__(self, size):
        super(ColorMatchEnv, self).__init__()

        self.velocity = 0
        self.difference = 0
        self.size = size
        # Action space: Increase or decrease R, G, B
        self.action_space = spaces.Discrete(6)  
        self.observation_space = spaces.Box(low=0, high=self.size, shape=(6,), dtype=np.int16)
    
    
    def step(self, action):
        
        prev_color = self.current_color.copy()
        
        step_size = 1
        if action == 0: self.current_color[0] += step_size  # Increase R
        elif action == 1: self.current_color[0] -= step_size  # Decrease R
        elif action == 2: self.current_color[1] += step_size  # Increase G
        elif action == 3: self.current_color[1] -= step_size  # Decrease G
        elif action == 4: self.current_color[2] += step_size  # Increase B
        elif action == 5: self.current_color[2] -= step_size  # Decrease B

        # Clamp values between 0 and 1
        self.current_color = np.clip(self.current_color, 0, self.size)
        max_distance = np.linalg.norm(np.array([self.size, self.size, self.size]))
        prev_distance = np.linalg.norm(self.target_color - prev_color) / max_distance
        new_distance = np.linalg.norm(self.target_color - self.current_color) / max_distance
        
        reward_r = self.direction_reward(self.current_color[0], self.target_color[0], prev_color[0])
        reward_g = self.direction_reward(self.current_color[1], self.target_color[1], prev_color[1])
        reward_b = self.direction_reward(self.current_color[2], self.target_color[2], prev_color[2])
        reward = (reward_r + reward_g + reward_b) / 3

        self.difference = prev_distance - new_distance
        # Done if very close to target
        done = np.linalg.norm(self.current_color - self.target_color) < 0.01
        truncated = False
        observation = self._get_obs()
        info = self._get_info()
    
        return observation, reward, done.all(), truncated, info
    
    def direction_reward(self, agent_position, target_position, prev_position):
        distance_to_target = np.abs(target_position - agent_position)
        prev_distance = np.abs(target_position - prev_position)
    
        if distance_to_target < 0.1:
            return 1  # Large reward for reaching the goal
    
        if np.abs(agent_position - prev_position) == 0:
            return -0.1  # Small penalty for no movement
    
        if distance_to_target > prev_distance:
            return -0.5  # Mild penalty for moving away
        
        #return 1 - np.abs(target_position - agent_position)
        return 1 / (1 + distance_to_target)  # Reward inversely proportional to distance
    
    def velocity_reward(self, agent_position, target_position, agent_velocity):
        direction_to_target = target_position - agent_position
        direction_to_target /= np.linalg.norm(direction_to_target)  # Normalize direction
        velocity_dot_product = np.dot(agent_velocity, direction_to_target)
        return velocity_dot_product
    
    def smooth_reward(self, agent_position, target_position, agent_velocity, lambda_factor=1):
        # distance = np.linalg.norm(agent_position - target_position)
        distance = 1 - np.linalg.norm(self.target_color - self.current_color)
        #distance = pow(distance, 2)
        direction_to_target = target_position - agent_position
        direction_to_target /= np.linalg.norm(direction_to_target)  # Normalize direction
        velocity_dot_product = np.dot(agent_velocity, direction_to_target)
        
        return distance + lambda_factor * velocity_dot_product

    def _get_obs(self):
        return np.concatenate([self.current_color, self.target_color])
    
    def _get_info(self):
        return { "distance" : np.linalg.norm(self.current_color - self.target_color), "velocity" : self.velocity, "difference" : self.difference}
    
    def reset(self, seed: Optional[int] = None, options: Optional[dict] = None):
        super().reset(seed=seed)
        self.target_color = self.np_random.integers(0, self.size, size=3) # New target
        self.current_color = self.np_random.integers(0, self.size, size=3)  # Reset color

        observation = self._get_obs()
        info = self._get_info()

        return observation, info

log_dir = "./ppo_logs/"
new_logger = configure(log_dir, ["csv", "tensorboard"])
print(torch.cuda.is_available())  # Should return True
print(torch.cuda.device_count())  # Number of available GPUs
# Train with PPO
env = ColorMatchEnv(256)
# env = DummyVecEnv([lambda: ColorMatchEnv()])
# env = VecNormalize(env, norm_reward=True)
env = Monitor(env, log_dir)
model = PPO("MlpPolicy", env, verbose=1, clip_range=0.2, device="cpu", learning_rate=0.00002, ent_coef=0.2, gae_lambda=0.99, vf_coef=0.2, n_epochs=5, batch_size=256)
model.set_logger(new_logger)
model.learn(total_timesteps=10000000)

print(torch.cuda.is_available())  # Should return True
print(torch.cuda.device_count())  # Number of available GPUs
# Out:
# False
# 0
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# False
# 0

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load PPO logs
log_file = "./ppo_logs/progress.csv"  # Make sure this path matches your logger output
data = pd.read_csv(log_file)
print(data.columns)

# Plot Episode Rewards
plt.figure(figsize=(12, 5))
plt.plot(data["time/total_timesteps"], data["rollout/ep_rew_mean"], label="Mean Episode Reward", color='b')
plt.xlabel("Timesteps")
plt.ylabel("Mean Reward")
plt.title("PPO Convergence: Episode Rewards Over Time")
plt.legend()
plt.grid()
plt.show()

# Plot Losses (Policy Gradient Loss & Value Loss)
plt.figure(figsize=(12, 5))
plt.plot(data["time/total_timesteps"], data["train/policy_gradient_loss"], label="Policy Gradient Loss", color='r')

plt.xlabel("Timesteps")
plt.ylabel("Loss")
plt.title("PPO Losses Over Time")
plt.legend()
plt.grid()
plt.show()

# Plot Losses (Policy Gradient Loss & Value Loss)
plt.figure(figsize=(12, 5))
# plt.plot(data["time/total_timesteps"], data["train/value_loss"], label="Value Loss", color='g')
plt.plot(data["time/total_timesteps"], data["train/entropy_loss"], label="Entropy Loss", color='b')
# plt.plot(data["time/total_timesteps"], data["train/value_loss"], label="Value Loss", color='g')
plt.xlabel("Timesteps")
plt.ylabel("Loss")
plt.title("Entropy Losses Over Time")
plt.legend()
plt.grid()
plt.show()

# Plot Losses (Policy Gradient Loss & Value Loss)
plt.figure(figsize=(12, 5))
# plt.plot(data["time/total_timesteps"], data["train/value_loss"], label="Value Loss", color='g')
# plt.plot(data["time/total_timesteps"], data["train/entropy_loss"], label="Entropy Loss", color='b')
plt.plot(data["time/total_timesteps"], data["train/value_loss"], label="Value Loss", color='g')
plt.xlabel("Timesteps")
plt.ylabel("Loss")
plt.title("PPO Losses Over Time")
plt.legend()
plt.grid()
plt.show()

# Plot KL Divergence (to check stability)
plt.figure(figsize=(12, 5))
plt.plot(data["time/total_timesteps"], data["train/approx_kl"], label="Approx KL", color='m')
plt.xlabel("Timesteps")
plt.ylabel("KL Divergence")
plt.title("PPO KL Divergence Over Time")
plt.legend()
plt.grid()
plt.show()
# Out:
# Index(['time/time_elapsed', 'time/iterations', 'time/total_timesteps',
#        'time/fps', 'train/n_updates', 'train/approx_kl', 'train/clip_fraction',
#        'train/loss', 'train/learning_rate', 'train/value_loss',
#        'train/entropy_loss', 'train/policy_gradient_loss', 'train/clip_range',
#        'train/explained_variance', 'rollout/ep_rew_mean',
#        'rollout/ep_len_mean'],
#       dtype='object')

# %%
# Test the trained agent
obs, _ = env.reset()
done = False
count = 0
while not done:
    count+=1
    action, _ = model.predict(obs)
    obs, reward, done, _, infos = env.step(action)
    direction = obs[3:] - obs[:3]
    max_distance = np.linalg.norm(np.array([1, 1, 1]))
    distance = np.linalg.norm(direction) / max_distance
    print(f"Distance {round(distance, 2)} Color: {obs[:3]}, Target: {obs[3:]}, {action} Reward: {round(reward, 2)}")
    # print(f"Distance {round(distance, 2)} Reward: {reward}")
    # print(f"Reward: {reward} Velocity: {round(infos['velocity'], 2)} Difference: {round(infos['difference'], 2)}")

print(f"Done in {count} steps")
# Out:
# Distance 53.9 Color: [ 81 250 181], Target: [108 182 239], 2 Reward: -0.23
# Distance 53.49 Color: [ 81 249 181], Target: [108 182 239], 3 Reward: -0.06
# Distance 53.32 Color: [ 82 249 181], Target: [108 182 239], 0 Reward: -0.05
# Distance 53.16 Color: [ 83 249 181], Target: [108 182 239], 0 Reward: -0.05
# Distance 52.8 Color: [ 83 249 182], Target: [108 182 239], 4 Reward: -0.06
# Distance 52.38 Color: [ 83 248 182], Target: [108 182 239], 3 Reward: -0.06
# Distance 52.54 Color: [ 82 248 182], Target: [108 182 239], 1 Reward: -0.23
# Distance 52.38 Color: [ 83 248 182], Target: [108 182 239], 0 Reward: -0.05
# Distance 52.22 Color: [ 84 248 182], Target: [108 182 239], 0 Reward: -0.05
# Distance 52.64 Color: [ 84 249 182], Target: [108 182 239], 2 Reward: -0.23
# Distance 52.49 Color: [ 85 249 182], Target: [108 182 239], 0 Reward: -0.05
# Distance 52.35 Color: [ 86 249 182], Target: [108 182 239], 0 Reward: -0.05
# Distance 51.93 Color: [ 86 248 182], Target: [108 182 239], 3 Reward: -0.06
# Distance 51.56 Color: [ 86 248 183], Target: [108 182 239], 4 Reward: -0.06
# Distance 51.2 Color: [ 86 248 184], Target: [108 182 239], 4 Reward: -0.06
# Distance 51.63 Color: [ 86 249 184], Target: [108 182 239], 2 Reward: -0.23
# Distance 51.78 Color: [ 85 249 184], Target: [108 182 239], 1 Reward: -0.23
# Distance 51.35 Color: [ 85 248 184], Target: [108 182 239], 3 Reward: -0.06
# Distance 50.99 Color: [ 85 248 185], Target: [108 182 239], 4 Reward: -0.06
# Distance 51.15 Color: [ 84 248 185], Target: [108 182 239], 1 Reward: -0.23
# Distance 50.99 Color: [ 85 248 185], Target: [108 182 239], 0 Reward: -0.05
# Distance 50.56 Color: [ 85 247 185], Target: [108 182 239], 3 Reward: -0.06
# Distance 50.92 Color: [ 85 247 184], Target: [108 182 239], 5 Reward: -0.23
# Distance 50.5 Color: [ 85 246 184], Target: [108 182 239], 3 Reward: -0.06
# Distance 50.14 Color: [ 85 246 185], Target: [108 182 239], 4 Reward: -0.06
# Distance 50.29 Color: [ 84 246 185], Target: [108 182 239], 1 Reward: -0.23
# Distance 49.87 Color: [ 84 245 185], Target: [108 182 239], 3 Reward: -0.06
# Distance 49.45 Color: [ 84 244 185], Target: [108 182 239], 3 Reward: -0.06
# Distance 49.09 Color: [ 84 244 186], Target: [108 182 239], 4 Reward: -0.06
# Distance 48.93 Color: [ 85 244 186], Target: [108 182 239], 0 Reward: -0.05
# Distance 48.51 Color: [ 85 243 186], Target: [108 182 239], 3 Reward: -0.06
# Distance 48.35 Color: [ 86 243 186], Target: [108 182 239], 0 Reward: -0.05
# Distance 48.2 Color: [ 87 243 186], Target: [108 182 239], 0 Reward: -0.05
# Distance 48.35 Color: [ 86 243 186], Target: [108 182 239], 1 Reward: -0.23
# Distance 48.2 Color: [ 87 243 186], Target: [108 182 239], 0 Reward: -0.05
# Distance 48.57 Color: [ 87 243 185], Target: [108 182 239], 5 Reward: -0.23
# Distance 48.72 Color: [ 86 243 185], Target: [108 182 239], 1 Reward: -0.23
# Distance 48.3 Color: [ 86 242 185], Target: [108 182 239], 3 Reward: -0.06
# Distance 48.68 Color: [ 86 242 184], Target: [108 182 239], 5 Reward: -0.23
# Distance 48.83 Color: [ 85 242 184], Target: [108 182 239], 1 Reward: -0.23
# Distance 48.99 Color: [ 84 242 184], Target: [108 182 239], 1 Reward: -0.23
# Distance 48.83 Color: [ 85 242 184], Target: [108 182 239], 0 Reward: -0.05
# Distance 48.68 Color: [ 86 242 184], Target: [108 182 239], 0 Reward: -0.05
# Distance 48.27 Color: [ 86 241 184], Target: [108 182 239], 3 Reward: -0.06
# Distance 47.86 Color: [ 86 240 184], Target: [108 182 239], 3 Reward: -0.06
# Distance 48.02 Color: [ 85 240 184], Target: [108 182 239], 1 Reward: -0.23
# Distance 47.86 Color: [ 86 240 184], Target: [108 182 239], 0 Reward: -0.05
# Distance 47.46 Color: [ 86 239 184], Target: [108 182 239], 3 Reward: -0.06
# Distance 47.08 Color: [ 86 239 185], Target: [108 182 239], 4 Reward: -0.06
# Distance 46.68 Color: [ 86 238 185], Target: [108 182 239], 3 Reward: -0.06
# Distance 46.28 Color: [ 86 237 185], Target: [108 182 239], 3 Reward: -0.06
# Distance 46.44 Color: [ 85 237 185], Target: [108 182 239], 1 Reward: -0.23
# Distance 46.83 Color: [ 85 237 184], Target: [108 182 239], 5 Reward: -0.23
# Distance 47.0 Color: [ 84 237 184], Target: [108 182 239], 1 Reward: -0.23
# Distance 46.83 Color: [ 85 237 184], Target: [108 182 239], 0 Reward: -0.05
# Distance 47.22 Color: [ 85 237 183], Target: [108 182 239], 5 Reward: -0.23
# Distance 47.39 Color: [ 84 237 183], Target: [108 182 239], 1 Reward: -0.23
# Distance 47.78 Color: [ 84 237 182], Target: [108 182 239], 5 Reward: -0.23
# Distance 47.4 Color: [ 84 236 182], Target: [108 182 239], 3 Reward: -0.06
# Distance 47.0 Color: [ 84 236 183], Target: [108 182 239], 4 Reward: -0.06
# Distance 47.4 Color: [ 84 236 182], Target: [108 182 239], 5 Reward: -0.23
# Distance 47.57 Color: [ 83 236 182], Target: [108 182 239], 1 Reward: -0.23
# Distance 47.95 Color: [ 83 237 182], Target: [108 182 239], 2 Reward: -0.23
# Distance 47.57 Color: [ 83 236 182], Target: [108 182 239], 3 Reward: -0.06
# Distance 47.75 Color: [ 82 236 182], Target: [108 182 239], 1 Reward: -0.23
# Distance 47.36 Color: [ 82 236 183], Target: [108 182 239], 4 Reward: -0.06
# Distance 47.18 Color: [ 83 236 183], Target: [108 182 239], 0 Reward: -0.05
# Distance 47.56 Color: [ 83 237 183], Target: [108 182 239], 2 Reward: -0.23
# Distance 47.39 Color: [ 84 237 183], Target: [108 182 239], 0 Reward: -0.05
# Distance 47.0 Color: [ 84 236 183], Target: [108 182 239], 3 Reward: -0.06
# Distance 46.61 Color: [ 84 236 184], Target: [108 182 239], 4 Reward: -0.06
# Distance 46.78 Color: [ 83 236 184], Target: [108 182 239], 1 Reward: -0.23
# Distance 46.96 Color: [ 82 236 184], Target: [108 182 239], 1 Reward: -0.23
# Distance 46.58 Color: [ 82 235 184], Target: [108 182 239], 3 Reward: -0.06
# Distance 46.98 Color: [ 82 235 183], Target: [108 182 239], 5 Reward: -0.23
# Distance 46.58 Color: [ 82 235 184], Target: [108 182 239], 4 Reward: -0.06
# Distance 46.4 Color: [ 83 235 184], Target: [108 182 239], 0 Reward: -0.05
# Distance 46.02 Color: [ 83 234 184], Target: [108 182 239], 3 Reward: -0.06
# Distance 46.42 Color: [ 83 234 183], Target: [108 182 239], 5 Reward: -0.23
# Distance 46.02 Color: [ 83 234 184], Target: [108 182 239], 4 Reward: -0.06
# Distance 46.42 Color: [ 83 234 183], Target: [108 182 239], 5 Reward: -0.23
# Distance 46.25 Color: [ 84 234 183], Target: [108 182 239], 0 Reward: -0.05
# Distance 46.65 Color: [ 84 234 182], Target: [108 182 239], 5 Reward: -0.23
# Distance 46.48 Color: [ 85 234 182], Target: [108 182 239], 0 Reward: -0.05
# Distance 46.11 Color: [ 85 233 182], Target: [108 182 239], 3 Reward: -0.06
# Distance 46.53 Color: [ 85 233 181], Target: [108 182 239], 5 Reward: -0.23
# Distance 46.16 Color: [ 85 232 181], Target: [108 182 239], 3 Reward: -0.06
# Distance 45.75 Color: [ 85 232 182], Target: [108 182 239], 4 Reward: -0.06
# Distance 45.38 Color: [ 85 231 182], Target: [108 182 239], 3 Reward: -0.06
# Distance 45.8 Color: [ 85 231 181], Target: [108 182 239], 5 Reward: -0.23
# Distance 45.64 Color: [ 86 231 181], Target: [108 182 239], 0 Reward: -0.05
# Distance 45.28 Color: [ 86 230 181], Target: [108 182 239], 3 Reward: -0.06
# Distance 45.64 Color: [ 86 231 181], Target: [108 182 239], 2 Reward: -0.23
# Distance 45.28 Color: [ 86 230 181], Target: [108 182 239], 3 Reward: -0.06
# Distance 45.71 Color: [ 86 230 180], Target: [108 182 239], 5 Reward: -0.23
# Distance 45.37 Color: [ 86 229 180], Target: [108 182 239], 3 Reward: -0.06
# Distance 45.53 Color: [ 85 229 180], Target: [108 182 239], 1 Reward: -0.23
# Distance 45.88 Color: [ 85 230 180], Target: [108 182 239], 2 Reward: -0.23
# Distance 45.71 Color: [ 86 230 180], Target: [108 182 239], 0 Reward: -0.05
# Distance 45.88 Color: [ 85 230 180], Target: [108 182 239], 1 Reward: -0.23
# Distance 45.53 Color: [ 85 229 180], Target: [108 182 239], 3 Reward: -0.06
# Distance 45.1 Color: [ 85 229 181], Target: [108 182 239], 4 Reward: -0.06
# Distance 45.53 Color: [ 85 229 180], Target: [108 182 239], 5 Reward: -0.23
# Distance 45.37 Color: [ 86 229 180], Target: [108 182 239], 0 Reward: -0.05
# Distance 45.02 Color: [ 86 228 180], Target: [108 182 239], 3 Reward: -0.06
# Distance 45.46 Color: [ 86 228 179], Target: [108 182 239], 5 Reward: -0.23
# Distance 45.8 Color: [ 86 229 179], Target: [108 182 239], 2 Reward: -0.23
# Distance 45.37 Color: [ 86 229 180], Target: [108 182 239], 4 Reward: -0.06
# Distance 45.21 Color: [ 87 229 180], Target: [108 182 239], 0 Reward: -0.05
# Distance 44.77 Color: [ 87 229 181], Target: [108 182 239], 4 Reward: -0.06
# Distance 44.43 Color: [ 87 228 181], Target: [108 182 239], 3 Reward: -0.06
# Distance 44.08 Color: [ 87 227 181], Target: [108 182 239], 3 Reward: -0.06
# Distance 44.52 Color: [ 87 227 180], Target: [108 182 239], 5 Reward: -0.23
# Distance 44.08 Color: [ 87 227 181], Target: [108 182 239], 4 Reward: -0.06
# Distance 44.52 Color: [ 87 227 180], Target: [108 182 239], 5 Reward: -0.23
# Distance 44.97 Color: [ 87 227 179], Target: [108 182 239], 5 Reward: -0.23
# Distance 44.64 Color: [ 87 226 179], Target: [108 182 239], 3 Reward: -0.06
# Distance 44.31 Color: [ 87 225 179], Target: [108 182 239], 3 Reward: -0.06
# Distance 43.99 Color: [ 87 224 179], Target: [108 182 239], 3 Reward: -0.06
# Distance 43.54 Color: [ 87 224 180], Target: [108 182 239], 4 Reward: -0.06
# Distance 43.22 Color: [ 87 223 180], Target: [108 182 239], 3 Reward: -0.06
# Distance 43.06 Color: [ 88 223 180], Target: [108 182 239], 0 Reward: -0.05
# Distance 43.52 Color: [ 88 223 179], Target: [108 182 239], 5 Reward: -0.23
# Distance 43.67 Color: [ 87 223 179], Target: [108 182 239], 1 Reward: -0.23
# Distance 43.52 Color: [ 88 223 179], Target: [108 182 239], 0 Reward: -0.05
# Distance 43.2 Color: [ 88 222 179], Target: [108 182 239], 3 Reward: -0.06
# Distance 42.9 Color: [ 88 221 179], Target: [108 182 239], 3 Reward: -0.06
# Distance 43.06 Color: [ 87 221 179], Target: [108 182 239], 1 Reward: -0.23
# Distance 43.52 Color: [ 87 221 178], Target: [108 182 239], 5 Reward: -0.23
# Distance 43.23 Color: [ 87 220 178], Target: [108 182 239], 3 Reward: -0.06
# Distance 43.39 Color: [ 86 220 178], Target: [108 182 239], 1 Reward: -0.23
# Distance 43.57 Color: [ 85 220 178], Target: [108 182 239], 1 Reward: -0.23
# Distance 43.28 Color: [ 85 219 178], Target: [108 182 239], 3 Reward: -0.06
# Distance 43.57 Color: [ 85 220 178], Target: [108 182 239], 2 Reward: -0.23
# Distance 43.1 Color: [ 85 220 179], Target: [108 182 239], 4 Reward: -0.06
# Distance 43.28 Color: [ 84 220 179], Target: [108 182 239], 1 Reward: -0.23
# Distance 43.1 Color: [ 85 220 179], Target: [108 182 239], 0 Reward: -0.05
# Distance 42.81 Color: [ 85 219 179], Target: [108 182 239], 3 Reward: -0.06
# Distance 43.1 Color: [ 85 220 179], Target: [108 182 239], 2 Reward: -0.23
# Distance 43.57 Color: [ 85 220 178], Target: [108 182 239], 5 Reward: -0.23
# Distance 43.39 Color: [ 86 220 178], Target: [108 182 239], 0 Reward: -0.05
# Distance 43.1 Color: [ 86 219 178], Target: [108 182 239], 3 Reward: -0.06
# Distance 42.94 Color: [ 87 219 178], Target: [108 182 239], 0 Reward: -0.05
# Distance 42.78 Color: [ 88 219 178], Target: [108 182 239], 0 Reward: -0.05
# Distance 43.26 Color: [ 88 219 177], Target: [108 182 239], 5 Reward: -0.23
# Distance 43.54 Color: [ 88 220 177], Target: [108 182 239], 2 Reward: -0.23
# Distance 43.07 Color: [ 88 220 178], Target: [108 182 239], 4 Reward: -0.06
# Distance 43.54 Color: [ 88 220 177], Target: [108 182 239], 5 Reward: -0.23
# Distance 44.02 Color: [ 88 220 176], Target: [108 182 239], 5 Reward: -0.23
# Distance 44.31 Color: [ 88 221 176], Target: [108 182 239], 2 Reward: -0.23
# Distance 44.16 Color: [ 89 221 176], Target: [108 182 239], 0 Reward: -0.05
# Distance 43.69 Color: [ 89 221 177], Target: [108 182 239], 4 Reward: -0.06
# Distance 44.16 Color: [ 89 221 176], Target: [108 182 239], 5 Reward: -0.23
# Distance 43.69 Color: [ 89 221 177], Target: [108 182 239], 4 Reward: -0.06
# Distance 43.39 Color: [ 89 220 177], Target: [108 182 239], 3 Reward: -0.06
# Distance 43.54 Color: [ 88 220 177], Target: [108 182 239], 1 Reward: -0.23
# Distance 43.26 Color: [ 88 219 177], Target: [108 182 239], 3 Reward: -0.06
# Distance 42.97 Color: [ 88 218 177], Target: [108 182 239], 3 Reward: -0.06
# Distance 43.13 Color: [ 87 218 177], Target: [108 182 239], 1 Reward: -0.23
# Distance 42.65 Color: [ 87 218 178], Target: [108 182 239], 4 Reward: -0.06
# Distance 42.38 Color: [ 87 217 178], Target: [108 182 239], 3 Reward: -0.06
# Distance 42.1 Color: [ 87 216 178], Target: [108 182 239], 3 Reward: -0.06
# Distance 41.84 Color: [ 87 215 178], Target: [108 182 239], 3 Reward: -0.06
# Distance 41.58 Color: [ 87 214 178], Target: [108 182 239], 3 Reward: -0.06
# Distance 42.07 Color: [ 87 214 177], Target: [108 182 239], 5 Reward: -0.23
# Distance 41.9 Color: [ 88 214 177], Target: [108 182 239], 0 Reward: -0.05
# Distance 41.75 Color: [ 89 214 177], Target: [108 182 239], 0 Reward: -0.05
# Distance 42.01 Color: [ 89 215 177], Target: [108 182 239], 2 Reward: -0.23
# Distance 41.75 Color: [ 89 214 177], Target: [108 182 239], 3 Reward: -0.06
# Distance 41.9 Color: [ 88 214 177], Target: [108 182 239], 1 Reward: -0.23
# Distance 41.65 Color: [ 88 213 177], Target: [108 182 239], 3 Reward: -0.06
# Distance 41.41 Color: [ 88 212 177], Target: [108 182 239], 3 Reward: -0.06
# Distance 41.17 Color: [ 88 211 177], Target: [108 182 239], 3 Reward: -0.06
# Distance 40.67 Color: [ 88 211 178], Target: [108 182 239], 4 Reward: -0.06
# Distance 41.17 Color: [ 88 211 177], Target: [108 182 239], 5 Reward: -0.23
# Distance 40.94 Color: [ 88 210 177], Target: [108 182 239], 3 Reward: -0.06
# Distance 41.11 Color: [ 87 210 177], Target: [108 182 239], 1 Reward: -0.23
# Distance 40.6 Color: [ 87 210 178], Target: [108 182 239], 4 Reward: -0.06
# Distance 40.84 Color: [ 87 211 178], Target: [108 182 239], 2 Reward: -0.23
# Distance 41.34 Color: [ 87 211 177], Target: [108 182 239], 5 Reward: -0.23
# Distance 41.51 Color: [ 86 211 177], Target: [108 182 239], 1 Reward: -0.23
# Distance 41.28 Color: [ 86 210 177], Target: [108 182 239], 3 Reward: -0.06
# Distance 41.46 Color: [ 85 210 177], Target: [108 182 239], 1 Reward: -0.23
# Distance 41.24 Color: [ 85 209 177], Target: [108 182 239], 3 Reward: -0.05
# Distance 41.02 Color: [ 85 208 177], Target: [108 182 239], 3 Reward: -0.05
# Distance 40.52 Color: [ 85 208 178], Target: [108 182 239], 4 Reward: -0.06
# Distance 41.02 Color: [ 85 208 177], Target: [108 182 239], 5 Reward: -0.23
# Distance 40.82 Color: [ 85 207 177], Target: [108 182 239], 3 Reward: -0.05
# Distance 40.31 Color: [ 85 207 178], Target: [108 182 239], 4 Reward: -0.06
# Distance 40.52 Color: [ 85 208 178], Target: [108 182 239], 2 Reward: -0.23
# Distance 40.34 Color: [ 86 208 178], Target: [108 182 239], 0 Reward: -0.05
# Distance 40.84 Color: [ 86 208 177], Target: [108 182 239], 5 Reward: -0.23
# Distance 40.34 Color: [ 86 208 178], Target: [108 182 239], 4 Reward: -0.06
# Distance 40.55 Color: [ 86 209 178], Target: [108 182 239], 2 Reward: -0.23
# Distance 40.05 Color: [ 86 209 179], Target: [108 182 239], 4 Reward: -0.06
# Distance 40.24 Color: [ 85 209 179], Target: [108 182 239], 1 Reward: -0.23
# Distance 40.74 Color: [ 85 209 178], Target: [108 182 239], 5 Reward: -0.23
# Distance 41.24 Color: [ 85 209 177], Target: [108 182 239], 5 Reward: -0.23
# Distance 41.43 Color: [ 84 209 177], Target: [108 182 239], 1 Reward: -0.23
# Distance 41.24 Color: [ 85 209 177], Target: [108 182 239], 0 Reward: -0.05
# Distance 40.74 Color: [ 85 209 178], Target: [108 182 239], 4 Reward: -0.06
# Distance 41.24 Color: [ 85 209 177], Target: [108 182 239], 5 Reward: -0.23
# Distance 41.02 Color: [ 85 208 177], Target: [108 182 239], 3 Reward: -0.05
# Distance 40.52 Color: [ 85 208 178], Target: [108 182 239], 4 Reward: -0.06
# Distance 40.34 Color: [ 86 208 178], Target: [108 182 239], 0 Reward: -0.05
# Distance 40.12 Color: [ 86 207 178], Target: [108 182 239], 3 Reward: -0.05
# Distance 40.63 Color: [ 86 207 177], Target: [108 182 239], 5 Reward: -0.23
# Distance 40.82 Color: [ 85 207 177], Target: [108 182 239], 1 Reward: -0.23
# Distance 40.31 Color: [ 85 207 178], Target: [108 182 239], 4 Reward: -0.06
# Distance 40.12 Color: [ 86 207 178], Target: [108 182 239], 0 Reward: -0.05
# Distance 39.95 Color: [ 87 207 178], Target: [108 182 239], 0 Reward: -0.05
# Distance 40.16 Color: [ 87 208 178], Target: [108 182 239], 2 Reward: -0.23
# Distance 39.95 Color: [ 87 207 178], Target: [108 182 239], 3 Reward: -0.05
# Distance 39.77 Color: [ 88 207 178], Target: [108 182 239], 0 Reward: -0.05
# Distance 40.29 Color: [ 88 207 177], Target: [108 182 239], 5 Reward: -0.23
# Distance 40.08 Color: [ 88 206 177], Target: [108 182 239], 3 Reward: -0.05
# Distance 39.92 Color: [ 89 206 177], Target: [108 182 239], 0 Reward: -0.05
# Distance 39.77 Color: [ 90 206 177], Target: [108 182 239], 0 Reward: -0.05
# Distance 39.25 Color: [ 90 206 178], Target: [108 182 239], 4 Reward: -0.06
# Distance 38.73 Color: [ 90 206 179], Target: [108 182 239], 4 Reward: -0.06
# Distance 38.58 Color: [ 91 206 179], Target: [108 182 239], 0 Reward: -0.05
# Distance 38.06 Color: [ 91 206 180], Target: [108 182 239], 4 Reward: -0.06
# Distance 38.28 Color: [ 91 207 180], Target: [108 182 239], 2 Reward: -0.23
# Distance 37.76 Color: [ 91 207 181], Target: [108 182 239], 4 Reward: -0.06
# Distance 37.92 Color: [ 90 207 181], Target: [108 182 239], 1 Reward: -0.23
# Distance 38.08 Color: [ 89 207 181], Target: [108 182 239], 1 Reward: -0.23
# Distance 37.92 Color: [ 90 207 181], Target: [108 182 239], 0 Reward: -0.05
# Distance 37.7 Color: [ 90 206 181], Target: [108 182 239], 3 Reward: -0.05
# Distance 37.49 Color: [ 90 205 181], Target: [108 182 239], 3 Reward: -0.05
# Distance 37.7 Color: [ 90 206 181], Target: [108 182 239], 2 Reward: -0.23
# Distance 37.19 Color: [ 90 206 182], Target: [108 182 239], 4 Reward: -0.06
# Distance 36.98 Color: [ 90 205 182], Target: [108 182 239], 3 Reward: -0.05
# Distance 36.46 Color: [ 90 205 183], Target: [108 182 239], 4 Reward: -0.06
# Distance 36.3 Color: [ 91 205 183], Target: [108 182 239], 0 Reward: -0.05
# Distance 36.46 Color: [ 90 205 183], Target: [108 182 239], 1 Reward: -0.23
# Distance 36.98 Color: [ 90 205 182], Target: [108 182 239], 5 Reward: -0.23
# Distance 36.46 Color: [ 90 205 183], Target: [108 182 239], 4 Reward: -0.06
# Distance 35.95 Color: [ 90 205 184], Target: [108 182 239], 4 Reward: -0.06
# Distance 35.79 Color: [ 91 205 184], Target: [108 182 239], 0 Reward: -0.05
# Distance 35.58 Color: [ 91 204 184], Target: [108 182 239], 3 Reward: -0.05
# Distance 35.74 Color: [ 90 204 184], Target: [108 182 239], 1 Reward: -0.23
# Distance 35.92 Color: [ 89 204 184], Target: [108 182 239], 1 Reward: -0.23
# Distance 36.12 Color: [ 89 205 184], Target: [108 182 239], 2 Reward: -0.23
# Distance 36.63 Color: [ 89 205 183], Target: [108 182 239], 5 Reward: -0.23
# Distance 36.43 Color: [ 89 204 183], Target: [108 182 239], 3 Reward: -0.05
# Distance 36.23 Color: [ 89 203 183], Target: [108 182 239], 3 Reward: -0.05
# Distance 36.06 Color: [ 90 203 183], Target: [108 182 239], 0 Reward: -0.05
# Distance 36.26 Color: [ 90 204 183], Target: [108 182 239], 2 Reward: -0.23
# Distance 35.74 Color: [ 90 204 184], Target: [108 182 239], 4 Reward: -0.06
# Distance 35.54 Color: [ 90 203 184], Target: [108 182 239], 3 Reward: -0.05
# Distance 35.74 Color: [ 90 204 184], Target: [108 182 239], 2 Reward: -0.23
# Distance 35.23 Color: [ 90 204 185], Target: [108 182 239], 4 Reward: -0.06
# Distance 35.44 Color: [ 90 205 185], Target: [108 182 239], 2 Reward: -0.23
# Distance 35.23 Color: [ 90 204 185], Target: [108 182 239], 3 Reward: -0.05
# Distance 34.72 Color: [ 90 204 186], Target: [108 182 239], 4 Reward: -0.06
# Distance 34.55 Color: [ 91 204 186], Target: [108 182 239], 0 Reward: -0.05
# Distance 34.35 Color: [ 91 203 186], Target: [108 182 239], 3 Reward: -0.05
# Distance 33.83 Color: [ 91 203 187], Target: [108 182 239], 4 Reward: -0.06
# Distance 33.67 Color: [ 92 203 187], Target: [108 182 239], 0 Reward: -0.05
# Distance 34.19 Color: [ 92 203 186], Target: [108 182 239], 5 Reward: -0.23
# Distance 34.03 Color: [ 93 203 186], Target: [108 182 239], 0 Reward: -0.05
# Distance 33.52 Color: [ 93 203 187], Target: [108 182 239], 4 Reward: -0.06
# Distance 33.31 Color: [ 93 202 187], Target: [108 182 239], 3 Reward: -0.05
# Distance 33.17 Color: [ 94 202 187], Target: [108 182 239], 0 Reward: -0.04
# Distance 33.31 Color: [ 93 202 187], Target: [108 182 239], 1 Reward: -0.23
# Distance 32.79 Color: [ 93 202 188], Target: [108 182 239], 4 Reward: -0.06
# Distance 32.27 Color: [ 93 202 189], Target: [108 182 239], 4 Reward: -0.06
# Distance 31.76 Color: [ 93 202 190], Target: [108 182 239], 4 Reward: -0.06
# Distance 31.25 Color: [ 93 202 191], Target: [108 182 239], 4 Reward: -0.06
# Distance 31.04 Color: [ 93 201 191], Target: [108 182 239], 3 Reward: -0.05
# Distance 30.84 Color: [ 93 200 191], Target: [108 182 239], 3 Reward: -0.05
# Distance 30.68 Color: [ 94 200 191], Target: [108 182 239], 0 Reward: -0.04
# Distance 31.2 Color: [ 94 200 190], Target: [108 182 239], 5 Reward: -0.23
# Distance 31.02 Color: [ 94 199 190], Target: [108 182 239], 3 Reward: -0.05
# Distance 30.87 Color: [ 95 199 190], Target: [108 182 239], 0 Reward: -0.04
# Distance 31.02 Color: [ 94 199 190], Target: [108 182 239], 1 Reward: -0.23
# Distance 30.84 Color: [ 94 198 190], Target: [108 182 239], 3 Reward: -0.05
# Distance 30.31 Color: [ 94 198 191], Target: [108 182 239], 4 Reward: -0.06
# Distance 29.78 Color: [ 94 198 192], Target: [108 182 239], 4 Reward: -0.06
# Distance 29.26 Color: [ 94 198 193], Target: [108 182 239], 4 Reward: -0.06
# Distance 29.42 Color: [ 93 198 193], Target: [108 182 239], 1 Reward: -0.23
# Distance 29.94 Color: [ 93 198 192], Target: [108 182 239], 5 Reward: -0.23
# Distance 29.77 Color: [ 93 197 192], Target: [108 182 239], 3 Reward: -0.05
# Distance 29.61 Color: [ 93 196 192], Target: [108 182 239], 3 Reward: -0.04
# Distance 29.44 Color: [ 94 196 192], Target: [108 182 239], 0 Reward: -0.04
# Distance 29.61 Color: [ 93 196 192], Target: [108 182 239], 1 Reward: -0.23
# Distance 29.46 Color: [ 93 195 192], Target: [108 182 239], 3 Reward: -0.04
# Distance 28.93 Color: [ 93 195 193], Target: [108 182 239], 4 Reward: -0.06
# Distance 29.1 Color: [ 92 195 193], Target: [108 182 239], 1 Reward: -0.23
# Distance 28.58 Color: [ 92 195 194], Target: [108 182 239], 4 Reward: -0.06
# Distance 28.4 Color: [ 93 195 194], Target: [108 182 239], 0 Reward: -0.05
# Distance 28.23 Color: [ 94 195 194], Target: [108 182 239], 0 Reward: -0.04
# Distance 27.69 Color: [ 94 195 195], Target: [108 182 239], 4 Reward: -0.06
# Distance 27.87 Color: [ 93 195 195], Target: [108 182 239], 1 Reward: -0.23
# Distance 27.72 Color: [ 93 194 195], Target: [108 182 239], 3 Reward: -0.04
# Distance 27.87 Color: [ 93 195 195], Target: [108 182 239], 2 Reward: -0.23
# Distance 28.4 Color: [ 93 195 194], Target: [108 182 239], 5 Reward: -0.23
# Distance 27.87 Color: [ 93 195 195], Target: [108 182 239], 4 Reward: -0.06
# Distance 27.72 Color: [ 93 194 195], Target: [108 182 239], 3 Reward: -0.04
# Distance 27.19 Color: [ 93 194 196], Target: [108 182 239], 4 Reward: -0.06
# Distance 27.01 Color: [ 94 194 196], Target: [108 182 239], 0 Reward: -0.04
# Distance 27.54 Color: [ 94 194 195], Target: [108 182 239], 5 Reward: -0.23
# Distance 27.01 Color: [ 94 194 196], Target: [108 182 239], 4 Reward: -0.06
# Distance 27.17 Color: [ 94 195 196], Target: [108 182 239], 2 Reward: -0.23
# Distance 26.64 Color: [ 94 195 197], Target: [108 182 239], 4 Reward: -0.06
# Distance 26.48 Color: [ 94 194 197], Target: [108 182 239], 3 Reward: -0.04
# Distance 26.64 Color: [ 94 195 197], Target: [108 182 239], 2 Reward: -0.23
# Distance 26.48 Color: [ 94 194 197], Target: [108 182 239], 3 Reward: -0.04
# Distance 26.34 Color: [ 94 193 197], Target: [108 182 239], 3 Reward: -0.04
# Distance 26.17 Color: [ 95 193 197], Target: [108 182 239], 0 Reward: -0.04
# Distance 25.63 Color: [ 95 193 198], Target: [108 182 239], 4 Reward: -0.06
# Distance 25.1 Color: [ 95 193 199], Target: [108 182 239], 4 Reward: -0.06
# Distance 25.25 Color: [ 95 194 199], Target: [108 182 239], 2 Reward: -0.23
# Distance 25.1 Color: [ 95 193 199], Target: [108 182 239], 3 Reward: -0.04
# Distance 24.93 Color: [ 96 193 199], Target: [108 182 239], 0 Reward: -0.04
# Distance 24.4 Color: [ 96 193 200], Target: [108 182 239], 4 Reward: -0.06
# Distance 24.24 Color: [ 97 193 200], Target: [108 182 239], 0 Reward: -0.04
# Distance 24.78 Color: [ 97 193 199], Target: [108 182 239], 5 Reward: -0.23
# Distance 24.64 Color: [ 98 193 199], Target: [108 182 239], 0 Reward: -0.04
# Distance 24.1 Color: [ 98 193 200], Target: [108 182 239], 4 Reward: -0.06
# Distance 23.56 Color: [ 98 193 201], Target: [108 182 239], 4 Reward: -0.06
# Distance 23.42 Color: [ 99 193 201], Target: [108 182 239], 0 Reward: -0.03
# Distance 22.88 Color: [ 99 193 202], Target: [108 182 239], 4 Reward: -0.06
# Distance 23.05 Color: [ 99 194 202], Target: [108 182 239], 2 Reward: -0.23
# Distance 22.52 Color: [ 99 194 203], Target: [108 182 239], 4 Reward: -0.06
# Distance 22.39 Color: [100 194 203], Target: [108 182 239], 0 Reward: -0.03
# Distance 22.22 Color: [100 193 203], Target: [108 182 239], 3 Reward: -0.04
# Distance 22.39 Color: [100 194 203], Target: [108 182 239], 2 Reward: -0.23
# Distance 22.58 Color: [100 195 203], Target: [108 182 239], 2 Reward: -0.23
# Distance 22.46 Color: [101 195 203], Target: [108 182 239], 0 Reward: -0.03
# Distance 23.0 Color: [101 195 202], Target: [108 182 239], 5 Reward: -0.23
# Distance 23.19 Color: [101 196 202], Target: [108 182 239], 2 Reward: -0.23
# Distance 22.66 Color: [101 196 203], Target: [108 182 239], 4 Reward: -0.06
# Distance 22.77 Color: [100 196 203], Target: [108 182 239], 1 Reward: -0.23
# Distance 22.66 Color: [101 196 203], Target: [108 182 239], 0 Reward: -0.03
# Distance 22.77 Color: [100 196 203], Target: [108 182 239], 1 Reward: -0.23
# Distance 22.99 Color: [100 197 203], Target: [108 182 239], 2 Reward: -0.23
# Distance 22.88 Color: [101 197 203], Target: [108 182 239], 0 Reward: -0.03
# Distance 22.78 Color: [102 197 203], Target: [108 182 239], 0 Reward: -0.02
# Distance 22.7 Color: [103 197 203], Target: [108 182 239], 0 Reward: -0.01
# Distance 22.63 Color: [104 197 203], Target: [108 182 239], 0 Reward: 0.0
# Distance 22.86 Color: [104 198 203], Target: [108 182 239], 2 Reward: -0.23
# Distance 22.81 Color: [105 198 203], Target: [108 182 239], 0 Reward: 0.02
# Distance 22.86 Color: [104 198 203], Target: [108 182 239], 1 Reward: -0.23
# Distance 22.81 Color: [105 198 203], Target: [108 182 239], 0 Reward: 0.02
# Distance 23.34 Color: [105 198 202], Target: [108 182 239], 5 Reward: -0.23
# Distance 23.3 Color: [106 198 202], Target: [108 182 239], 0 Reward: 0.04
# Distance 23.83 Color: [106 198 201], Target: [108 182 239], 5 Reward: -0.23
# Distance 23.3 Color: [106 198 202], Target: [108 182 239], 4 Reward: -0.06
# Distance 23.08 Color: [106 197 202], Target: [108 182 239], 3 Reward: -0.05
# Distance 23.06 Color: [107 197 202], Target: [108 182 239], 0 Reward: 0.1
# Distance 22.85 Color: [107 196 202], Target: [108 182 239], 3 Reward: -0.04
# Distance 22.84 Color: [108 196 202], Target: [108 182 239], 0 Reward: 0.27
# Distance 22.85 Color: [107 196 202], Target: [108 182 239], 1 Reward: -0.23
# Distance 23.06 Color: [107 197 202], Target: [108 182 239], 2 Reward: -0.23
# Distance 22.85 Color: [107 196 202], Target: [108 182 239], 3 Reward: -0.04
# Distance 23.39 Color: [107 196 201], Target: [108 182 239], 5 Reward: -0.23
# Distance 23.19 Color: [107 195 201], Target: [108 182 239], 3 Reward: -0.04
# Distance 23.22 Color: [106 195 201], Target: [108 182 239], 1 Reward: -0.23
# Distance 23.41 Color: [106 196 201], Target: [108 182 239], 2 Reward: -0.23
# Distance 23.44 Color: [105 196 201], Target: [108 182 239], 1 Reward: -0.23
# Distance 23.99 Color: [105 196 200], Target: [108 182 239], 5 Reward: -0.23
# Distance 23.8 Color: [105 195 200], Target: [108 182 239], 3 Reward: -0.04
# Distance 23.76 Color: [106 195 200], Target: [108 182 239], 0 Reward: 0.04
# Distance 23.59 Color: [106 194 200], Target: [108 182 239], 3 Reward: -0.04
# Distance 23.62 Color: [105 194 200], Target: [108 182 239], 1 Reward: -0.23
# Distance 23.59 Color: [106 194 200], Target: [108 182 239], 0 Reward: 0.04
# Distance 23.57 Color: [107 194 200], Target: [108 182 239], 0 Reward: 0.1
# Distance 23.59 Color: [106 194 200], Target: [108 182 239], 1 Reward: -0.23
# Distance 24.14 Color: [106 194 199], Target: [108 182 239], 5 Reward: -0.23
# Distance 24.12 Color: [107 194 199], Target: [108 182 239], 0 Reward: 0.1
# Distance 24.29 Color: [107 195 199], Target: [108 182 239], 2 Reward: -0.23
# Distance 24.47 Color: [107 196 199], Target: [108 182 239], 2 Reward: -0.23
# Distance 24.47 Color: [108 196 199], Target: [108 182 239], 0 Reward: 0.27
# Distance 24.47 Color: [109 196 199], Target: [108 182 239], 0 Reward: -0.23
# Distance 24.29 Color: [109 195 199], Target: [108 182 239], 3 Reward: -0.04
# Distance 24.31 Color: [110 195 199], Target: [108 182 239], 0 Reward: -0.23
# Distance 24.34 Color: [111 195 199], Target: [108 182 239], 0 Reward: -0.23
# Distance 23.8 Color: [111 195 200], Target: [108 182 239], 4 Reward: -0.06
# Distance 23.85 Color: [112 195 200], Target: [108 182 239], 0 Reward: -0.23
# Distance 24.03 Color: [112 196 200], Target: [108 182 239], 2 Reward: -0.23
# Distance 24.58 Color: [112 196 199], Target: [108 182 239], 5 Reward: -0.23
# Distance 24.77 Color: [112 197 199], Target: [108 182 239], 2 Reward: -0.23
# Distance 24.58 Color: [112 196 199], Target: [108 182 239], 3 Reward: -0.04
# Distance 24.64 Color: [113 196 199], Target: [108 182 239], 0 Reward: -0.23
# Distance 24.1 Color: [113 196 200], Target: [108 182 239], 4 Reward: -0.06
# Distance 23.91 Color: [113 195 200], Target: [108 182 239], 3 Reward: -0.04
# Distance 24.1 Color: [113 196 200], Target: [108 182 239], 2 Reward: -0.23
# Distance 23.91 Color: [113 195 200], Target: [108 182 239], 3 Reward: -0.04
# Distance 24.45 Color: [113 195 199], Target: [108 182 239], 5 Reward: -0.23
# Distance 24.53 Color: [114 195 199], Target: [108 182 239], 0 Reward: -0.23
# Distance 23.99 Color: [114 195 200], Target: [108 182 239], 4 Reward: -0.06
# Distance 23.44 Color: [114 195 201], Target: [108 182 239], 4 Reward: -0.06
# Distance 23.37 Color: [113 195 201], Target: [108 182 239], 1 Reward: -0.01
# Distance 23.3 Color: [112 195 201], Target: [108 182 239], 1 Reward: 0.0
# Distance 23.37 Color: [113 195 201], Target: [108 182 239], 0 Reward: -0.23
# Distance 22.83 Color: [113 195 202], Target: [108 182 239], 4 Reward: -0.06
# Distance 22.29 Color: [113 195 203], Target: [108 182 239], 4 Reward: -0.06
# Distance 22.22 Color: [112 195 203], Target: [108 182 239], 1 Reward: 0.0
# Distance 21.68 Color: [112 195 204], Target: [108 182 239], 4 Reward: -0.06
# Distance 21.75 Color: [113 195 204], Target: [108 182 239], 0 Reward: -0.23
# Distance 21.68 Color: [112 195 204], Target: [108 182 239], 1 Reward: 0.0
# Distance 21.63 Color: [111 195 204], Target: [108 182 239], 1 Reward: 0.02
# Distance 21.43 Color: [111 194 204], Target: [108 182 239], 3 Reward: -0.04
# Distance 21.25 Color: [111 193 204], Target: [108 182 239], 3 Reward: -0.04
# Distance 21.09 Color: [111 192 204], Target: [108 182 239], 3 Reward: -0.04
# Distance 21.64 Color: [111 192 203], Target: [108 182 239], 5 Reward: -0.23
# Distance 21.09 Color: [111 192 204], Target: [108 182 239], 4 Reward: -0.06
# Distance 20.94 Color: [111 191 204], Target: [108 182 239], 3 Reward: -0.03
# Distance 20.9 Color: [110 191 204], Target: [108 182 239], 1 Reward: 0.04
# Distance 20.94 Color: [111 191 204], Target: [108 182 239], 0 Reward: -0.23
# Distance 20.38 Color: [111 191 205], Target: [108 182 239], 4 Reward: -0.06
# Distance 20.24 Color: [111 190 205], Target: [108 182 239], 3 Reward: -0.03
# Distance 19.68 Color: [111 190 206], Target: [108 182 239], 4 Reward: -0.06
# Distance 19.64 Color: [110 190 206], Target: [108 182 239], 1 Reward: 0.04
# Distance 19.78 Color: [110 191 206], Target: [108 182 239], 2 Reward: -0.23
# Distance 19.76 Color: [109 191 206], Target: [108 182 239], 1 Reward: 0.1
# Distance 19.78 Color: [110 191 206], Target: [108 182 239], 0 Reward: -0.23
# Distance 19.94 Color: [110 192 206], Target: [108 182 239], 2 Reward: -0.23
# Distance 19.78 Color: [110 191 206], Target: [108 182 239], 3 Reward: -0.03
# Distance 19.76 Color: [109 191 206], Target: [108 182 239], 1 Reward: 0.1
# Distance 19.92 Color: [109 192 206], Target: [108 182 239], 2 Reward: -0.23
# Distance 20.09 Color: [109 193 206], Target: [108 182 239], 2 Reward: -0.23
# Distance 20.64 Color: [109 193 205], Target: [108 182 239], 5 Reward: -0.23
# Distance 21.19 Color: [109 193 204], Target: [108 182 239], 5 Reward: -0.23
# Distance 21.18 Color: [108 193 204], Target: [108 182 239], 1 Reward: 0.27
# Distance 21.02 Color: [108 192 204], Target: [108 182 239], 3 Reward: 0.33
# Distance 21.02 Color: [109 192 204], Target: [108 182 239], 0 Reward: -0.23
# Distance 21.58 Color: [109 192 203], Target: [108 182 239], 5 Reward: -0.23
# Distance 21.02 Color: [109 192 204], Target: [108 182 239], 4 Reward: -0.06
# Distance 20.87 Color: [109 191 204], Target: [108 182 239], 3 Reward: -0.03
# Distance 20.9 Color: [110 191 204], Target: [108 182 239], 0 Reward: -0.23
# Distance 20.34 Color: [110 191 205], Target: [108 182 239], 4 Reward: -0.06
# Distance 20.38 Color: [111 191 205], Target: [108 182 239], 0 Reward: -0.23
# Distance 20.24 Color: [111 190 205], Target: [108 182 239], 3 Reward: -0.03
# Distance 20.38 Color: [111 191 205], Target: [108 182 239], 2 Reward: -0.23
# Distance 20.44 Color: [112 191 205], Target: [108 182 239], 0 Reward: -0.23
# Distance 19.88 Color: [112 191 206], Target: [108 182 239], 4 Reward: -0.06
# Distance 19.33 Color: [112 191 207], Target: [108 182 239], 4 Reward: -0.06
# Distance 19.88 Color: [112 191 206], Target: [108 182 239], 5 Reward: -0.23
# Distance 19.82 Color: [111 191 206], Target: [108 182 239], 1 Reward: 0.02
# Distance 19.88 Color: [112 191 206], Target: [108 182 239], 0 Reward: -0.23
# Distance 19.74 Color: [112 190 206], Target: [108 182 239], 3 Reward: -0.03
# Distance 19.68 Color: [111 190 206], Target: [108 182 239], 1 Reward: 0.02
# Distance 19.74 Color: [112 190 206], Target: [108 182 239], 0 Reward: -0.23
# Distance 19.18 Color: [112 190 207], Target: [108 182 239], 4 Reward: -0.06
# Distance 19.74 Color: [112 190 206], Target: [108 182 239], 5 Reward: -0.23
# Distance 19.18 Color: [112 190 207], Target: [108 182 239], 4 Reward: -0.06
# Distance 18.63 Color: [112 190 208], Target: [108 182 239], 4 Reward: -0.06
# Distance 18.07 Color: [112 190 209], Target: [108 182 239], 4 Reward: -0.06
# Distance 18.63 Color: [112 190 208], Target: [108 182 239], 5 Reward: -0.23
# Distance 19.18 Color: [112 190 207], Target: [108 182 239], 5 Reward: -0.23
# Distance 19.05 Color: [112 189 207], Target: [108 182 239], 3 Reward: -0.03
# Distance 19.61 Color: [112 189 206], Target: [108 182 239], 5 Reward: -0.23
# Distance 20.17 Color: [112 189 205], Target: [108 182 239], 5 Reward: -0.23
# Distance 19.61 Color: [112 189 206], Target: [108 182 239], 4 Reward: -0.06
# Distance 19.74 Color: [112 190 206], Target: [108 182 239], 2 Reward: -0.23
# Distance 19.68 Color: [111 190 206], Target: [108 182 239], 1 Reward: 0.02
# Distance 19.74 Color: [112 190 206], Target: [108 182 239], 0 Reward: -0.23
# Distance 19.82 Color: [113 190 206], Target: [108 182 239], 0 Reward: -0.23
# Distance 19.91 Color: [114 190 206], Target: [108 182 239], 0 Reward: -0.23
# Distance 19.36 Color: [114 190 207], Target: [108 182 239], 4 Reward: -0.06
# Distance 18.81 Color: [114 190 208], Target: [108 182 239], 4 Reward: -0.06
# Distance 18.71 Color: [113 190 208], Target: [108 182 239], 1 Reward: -0.01
# Distance 18.16 Color: [113 190 209], Target: [108 182 239], 4 Reward: -0.06
# Distance 17.61 Color: [113 190 210], Target: [108 182 239], 4 Reward: -0.06
# Distance 17.52 Color: [112 190 210], Target: [108 182 239], 1 Reward: 0.0
# Distance 16.97 Color: [112 190 211], Target: [108 182 239], 4 Reward: -0.06
# Distance 16.42 Color: [112 190 212], Target: [108 182 239], 4 Reward: -0.05
# Distance 16.97 Color: [112 190 211], Target: [108 182 239], 5 Reward: -0.23
# Distance 16.42 Color: [112 190 212], Target: [108 182 239], 4 Reward: -0.05
# Distance 15.87 Color: [112 190 213], Target: [108 182 239], 4 Reward: -0.05
# Distance 16.42 Color: [112 190 212], Target: [108 182 239], 5 Reward: -0.23
# Distance 15.87 Color: [112 190 213], Target: [108 182 239], 4 Reward: -0.05
# Distance 15.97 Color: [113 190 213], Target: [108 182 239], 0 Reward: -0.23
# Distance 16.08 Color: [114 190 213], Target: [108 182 239], 0 Reward: -0.23
# Distance 15.55 Color: [114 190 214], Target: [108 182 239], 4 Reward: -0.05
# Distance 15.73 Color: [114 191 214], Target: [108 182 239], 2 Reward: -0.23
# Distance 15.61 Color: [113 191 214], Target: [108 182 239], 1 Reward: -0.01
# Distance 15.08 Color: [113 191 215], Target: [108 182 239], 4 Reward: -0.05
# Distance 15.29 Color: [113 192 215], Target: [108 182 239], 2 Reward: -0.23
# Distance 15.41 Color: [114 192 215], Target: [108 182 239], 0 Reward: -0.23
# Distance 15.55 Color: [115 192 215], Target: [108 182 239], 0 Reward: -0.23
# Distance 15.71 Color: [116 192 215], Target: [108 182 239], 0 Reward: -0.23
# Distance 16.22 Color: [116 192 214], Target: [108 182 239], 5 Reward: -0.23
# Distance 16.02 Color: [116 191 214], Target: [108 182 239], 3 Reward: -0.03
# Distance 15.5 Color: [116 191 215], Target: [108 182 239], 4 Reward: -0.05
# Distance 14.99 Color: [116 191 216], Target: [108 182 239], 4 Reward: -0.05
# Distance 15.2 Color: [116 192 216], Target: [108 182 239], 2 Reward: -0.23
# Distance 14.7 Color: [116 192 217], Target: [108 182 239], 4 Reward: -0.05
# Distance 14.53 Color: [115 192 217], Target: [108 182 239], 1 Reward: -0.03
# Distance 14.31 Color: [115 191 217], Target: [108 182 239], 3 Reward: -0.03
# Distance 14.11 Color: [115 190 217], Target: [108 182 239], 3 Reward: -0.03
# Distance 13.59 Color: [115 190 218], Target: [108 182 239], 4 Reward: -0.05
# Distance 13.4 Color: [115 189 218], Target: [108 182 239], 3 Reward: -0.03
# Distance 13.24 Color: [114 189 218], Target: [108 182 239], 1 Reward: -0.02
# Distance 12.71 Color: [114 189 219], Target: [108 182 239], 4 Reward: -0.05
# Distance 12.19 Color: [114 189 220], Target: [108 182 239], 4 Reward: -0.05
# Distance 12.71 Color: [114 189 219], Target: [108 182 239], 5 Reward: -0.23
# Distance 13.24 Color: [114 189 218], Target: [108 182 239], 5 Reward: -0.23
# Distance 13.1 Color: [113 189 218], Target: [108 182 239], 1 Reward: -0.01
# Distance 13.24 Color: [114 189 218], Target: [108 182 239], 0 Reward: -0.23
# Distance 13.1 Color: [113 189 218], Target: [108 182 239], 1 Reward: -0.01
# Distance 13.64 Color: [113 189 217], Target: [108 182 239], 5 Reward: -0.23
# Distance 13.53 Color: [112 189 217], Target: [108 182 239], 1 Reward: 0.0
# Distance 12.99 Color: [112 189 218], Target: [108 182 239], 4 Reward: -0.05
# Distance 12.45 Color: [112 189 219], Target: [108 182 239], 4 Reward: -0.05
# Distance 12.65 Color: [112 190 219], Target: [108 182 239], 2 Reward: -0.23
# Distance 12.45 Color: [112 189 219], Target: [108 182 239], 3 Reward: -0.03
# Distance 11.92 Color: [112 189 220], Target: [108 182 239], 4 Reward: -0.05
# Distance 12.04 Color: [113 189 220], Target: [108 182 239], 0 Reward: -0.23
# Distance 12.19 Color: [114 189 220], Target: [108 182 239], 0 Reward: -0.23
# Distance 12.01 Color: [114 188 220], Target: [108 182 239], 3 Reward: -0.02
# Distance 12.19 Color: [115 188 220], Target: [108 182 239], 0 Reward: -0.23
# Distance 12.71 Color: [115 188 219], Target: [108 182 239], 5 Reward: -0.23
# Distance 12.54 Color: [114 188 219], Target: [108 182 239], 1 Reward: -0.02
# Distance 12.4 Color: [113 188 219], Target: [108 182 239], 1 Reward: -0.01
# Distance 12.57 Color: [113 189 219], Target: [108 182 239], 2 Reward: -0.23
# Distance 12.77 Color: [113 190 219], Target: [108 182 239], 2 Reward: -0.23
# Distance 13.29 Color: [113 190 218], Target: [108 182 239], 5 Reward: -0.23
# Distance 13.82 Color: [113 190 217], Target: [108 182 239], 5 Reward: -0.23
# Distance 13.95 Color: [114 190 217], Target: [108 182 239], 0 Reward: -0.23
# Distance 14.11 Color: [115 190 217], Target: [108 182 239], 0 Reward: -0.23
# Distance 13.59 Color: [115 190 218], Target: [108 182 239], 4 Reward: -0.05
# Distance 13.8 Color: [115 191 218], Target: [108 182 239], 2 Reward: -0.23
# Distance 13.98 Color: [116 191 218], Target: [108 182 239], 0 Reward: -0.23
# Distance 13.8 Color: [115 191 218], Target: [108 182 239], 1 Reward: -0.03
# Distance 14.02 Color: [115 192 218], Target: [108 182 239], 2 Reward: -0.23
# Distance 14.2 Color: [116 192 218], Target: [108 182 239], 0 Reward: -0.23
# Distance 13.71 Color: [116 192 219], Target: [108 182 239], 4 Reward: -0.05
# Distance 13.53 Color: [115 192 219], Target: [108 182 239], 1 Reward: -0.03
# Distance 13.29 Color: [115 191 219], Target: [108 182 239], 3 Reward: -0.03
# Distance 13.48 Color: [116 191 219], Target: [108 182 239], 0 Reward: -0.23
# Distance 13.69 Color: [117 191 219], Target: [108 182 239], 0 Reward: -0.23
# Distance 13.92 Color: [117 192 219], Target: [108 182 239], 2 Reward: -0.23
# Distance 13.69 Color: [117 191 219], Target: [108 182 239], 3 Reward: -0.03
# Distance 13.92 Color: [117 192 219], Target: [108 182 239], 2 Reward: -0.23
# Distance 13.44 Color: [117 192 220], Target: [108 182 239], 4 Reward: -0.05
# Distance 13.23 Color: [116 192 220], Target: [108 182 239], 1 Reward: -0.03
# Distance 13.04 Color: [115 192 220], Target: [108 182 239], 1 Reward: -0.03
# Distance 12.79 Color: [115 191 220], Target: [108 182 239], 3 Reward: -0.03
# Distance 12.99 Color: [116 191 220], Target: [108 182 239], 0 Reward: -0.23
# Distance 13.23 Color: [116 192 220], Target: [108 182 239], 2 Reward: -0.23
# Distance 13.71 Color: [116 192 219], Target: [108 182 239], 5 Reward: -0.23
# Distance 13.23 Color: [116 192 220], Target: [108 182 239], 4 Reward: -0.05
# Distance 12.75 Color: [116 192 221], Target: [108 182 239], 4 Reward: -0.05
# Distance 13.23 Color: [116 192 220], Target: [108 182 239], 5 Reward: -0.23
# Distance 12.99 Color: [116 191 220], Target: [108 182 239], 3 Reward: -0.03
# Distance 12.5 Color: [116 191 221], Target: [108 182 239], 4 Reward: -0.05
# Distance 12.73 Color: [117 191 221], Target: [108 182 239], 0 Reward: -0.23
# Distance 12.5 Color: [117 190 221], Target: [108 182 239], 3 Reward: -0.03
# Distance 12.75 Color: [118 190 221], Target: [108 182 239], 0 Reward: -0.23
# Distance 12.56 Color: [118 189 221], Target: [108 182 239], 3 Reward: -0.03
# Distance 12.3 Color: [117 189 221], Target: [108 182 239], 1 Reward: -0.03
# Distance 11.82 Color: [117 189 222], Target: [108 182 239], 4 Reward: -0.05
# Distance 11.34 Color: [117 189 223], Target: [108 182 239], 4 Reward: -0.05
# Distance 11.15 Color: [117 188 223], Target: [108 182 239], 3 Reward: -0.02
# Distance 11.63 Color: [117 188 222], Target: [108 182 239], 5 Reward: -0.23
# Distance 11.15 Color: [117 188 223], Target: [108 182 239], 4 Reward: -0.05
# Distance 10.89 Color: [116 188 223], Target: [108 182 239], 1 Reward: -0.03
# Distance 11.15 Color: [117 188 223], Target: [108 182 239], 0 Reward: -0.23
# Distance 10.68 Color: [117 188 224], Target: [108 182 239], 4 Reward: -0.05
# Distance 10.41 Color: [116 188 224], Target: [108 182 239], 1 Reward: -0.03
# Distance 10.17 Color: [115 188 224], Target: [108 182 239], 1 Reward: -0.03
# Distance 10.41 Color: [116 188 224], Target: [108 182 239], 0 Reward: -0.23
# Distance 9.93 Color: [116 188 225], Target: [108 182 239], 4 Reward: -0.04
# Distance 10.15 Color: [116 189 225], Target: [108 182 239], 2 Reward: -0.23
# Distance 9.9 Color: [115 189 225], Target: [108 182 239], 1 Reward: -0.03
# Distance 9.43 Color: [115 189 226], Target: [108 182 239], 4 Reward: -0.04
# Distance 9.9 Color: [115 189 225], Target: [108 182 239], 5 Reward: -0.23
# Distance 10.15 Color: [116 189 225], Target: [108 182 239], 0 Reward: -0.23
# Distance 10.42 Color: [117 189 225], Target: [108 182 239], 0 Reward: -0.23
# Distance 10.15 Color: [116 189 225], Target: [108 182 239], 1 Reward: -0.03
# Distance 9.9 Color: [115 189 225], Target: [108 182 239], 1 Reward: -0.03
# Distance 9.68 Color: [115 188 225], Target: [108 182 239], 3 Reward: -0.02
# Distance 9.93 Color: [116 188 225], Target: [108 182 239], 0 Reward: -0.23
# Distance 9.68 Color: [115 188 225], Target: [108 182 239], 1 Reward: -0.03
# Distance 9.49 Color: [115 187 225], Target: [108 182 239], 3 Reward: -0.01
# Distance 9.26 Color: [114 187 225], Target: [108 182 239], 1 Reward: -0.02
# Distance 8.76 Color: [114 187 226], Target: [108 182 239], 4 Reward: -0.04
# Distance 8.96 Color: [114 188 226], Target: [108 182 239], 2 Reward: -0.23
# Distance 8.76 Color: [113 188 226], Target: [108 182 239], 1 Reward: -0.01
# Distance 8.54 Color: [113 187 226], Target: [108 182 239], 3 Reward: -0.01
# Distance 9.06 Color: [113 187 225], Target: [108 182 239], 5 Reward: -0.23
# Distance 8.54 Color: [113 187 226], Target: [108 182 239], 4 Reward: -0.04
# Distance 8.04 Color: [113 187 227], Target: [108 182 239], 4 Reward: -0.04
# Distance 7.85 Color: [112 187 227], Target: [108 182 239], 1 Reward: 0.0
# Distance 8.37 Color: [112 187 226], Target: [108 182 239], 5 Reward: -0.23
# Distance 7.85 Color: [112 187 227], Target: [108 182 239], 4 Reward: -0.04
# Distance 8.04 Color: [113 187 227], Target: [108 182 239], 0 Reward: -0.23
# Distance 8.27 Color: [113 188 227], Target: [108 182 239], 2 Reward: -0.23
# Distance 8.52 Color: [113 189 227], Target: [108 182 239], 2 Reward: -0.23
# Distance 8.27 Color: [113 188 227], Target: [108 182 239], 3 Reward: -0.02
# Distance 8.76 Color: [113 188 226], Target: [108 182 239], 5 Reward: -0.23
# Distance 8.27 Color: [113 188 227], Target: [108 182 239], 4 Reward: -0.04
# Distance 8.49 Color: [114 188 227], Target: [108 182 239], 0 Reward: -0.23
# Distance 8.96 Color: [114 188 226], Target: [108 182 239], 5 Reward: -0.23
# Distance 9.2 Color: [115 188 226], Target: [108 182 239], 0 Reward: -0.23
# Distance 9.47 Color: [116 188 226], Target: [108 182 239], 0 Reward: -0.23
# Distance 9.2 Color: [115 188 226], Target: [108 182 239], 1 Reward: -0.03
# Distance 8.96 Color: [114 188 226], Target: [108 182 239], 1 Reward: -0.02
# Distance 9.2 Color: [115 188 226], Target: [108 182 239], 0 Reward: -0.23
# Distance 9.0 Color: [115 187 226], Target: [108 182 239], 3 Reward: -0.01
# Distance 8.83 Color: [115 186 226], Target: [108 182 239], 3 Reward: 0.0
# Distance 8.35 Color: [115 186 227], Target: [108 182 239], 4 Reward: -0.04
# Distance 8.64 Color: [116 186 227], Target: [108 182 239], 0 Reward: -0.23
# Distance 8.35 Color: [115 186 227], Target: [108 182 239], 1 Reward: -0.03
# Distance 8.08 Color: [114 186 227], Target: [108 182 239], 1 Reward: -0.02
# Distance 7.94 Color: [114 185 227], Target: [108 182 239], 3 Reward: 0.02
# Distance 7.44 Color: [114 185 228], Target: [108 182 239], 4 Reward: -0.04
# Distance 7.19 Color: [113 185 228], Target: [108 182 239], 1 Reward: -0.01
# Distance 7.07 Color: [113 184 228], Target: [108 182 239], 3 Reward: 0.04
# Distance 6.56 Color: [113 184 229], Target: [108 182 239], 4 Reward: -0.04
# Distance 6.06 Color: [113 184 230], Target: [108 182 239], 4 Reward: -0.03
# Distance 6.35 Color: [114 184 230], Target: [108 182 239], 0 Reward: -0.23
# Distance 6.06 Color: [113 184 230], Target: [108 182 239], 1 Reward: -0.01
# Distance 6.56 Color: [113 184 229], Target: [108 182 239], 5 Reward: -0.23
# Distance 6.48 Color: [113 183 229], Target: [108 182 239], 3 Reward: 0.1
# Distance 6.56 Color: [113 184 229], Target: [108 182 239], 2 Reward: -0.23
# Distance 6.32 Color: [112 184 229], Target: [108 182 239], 1 Reward: 0.0
# Distance 6.24 Color: [112 183 229], Target: [108 182 239], 3 Reward: 0.1
# Distance 6.22 Color: [112 182 229], Target: [108 182 239], 3 Reward: 0.27
# Distance 6.45 Color: [113 182 229], Target: [108 182 239], 0 Reward: 0.13
# Distance 6.98 Color: [113 182 228], Target: [108 182 239], 5 Reward: 0.13
# Distance 7.23 Color: [114 182 228], Target: [108 182 239], 0 Reward: 0.13
# Distance 7.26 Color: [114 183 228], Target: [108 182 239], 2 Reward: -0.23
# Distance 7.23 Color: [114 182 228], Target: [108 182 239], 3 Reward: 0.27
# Distance 6.73 Color: [114 182 229], Target: [108 182 239], 4 Reward: 0.33
# Distance 6.76 Color: [114 183 229], Target: [108 182 239], 2 Reward: -0.23
# Distance 7.07 Color: [115 183 229], Target: [108 182 239], 0 Reward: -0.23
# Distance 7.42 Color: [116 183 229], Target: [108 182 239], 0 Reward: -0.23
# Distance 6.98 Color: [116 183 230], Target: [108 182 239], 4 Reward: -0.03
# Distance 6.56 Color: [116 183 231], Target: [108 182 239], 4 Reward: -0.03
# Distance 6.53 Color: [116 182 231], Target: [108 182 239], 3 Reward: 0.27
# ...
# Distance 3.37 Color: [113 182 236], Target: [108 182 239], 2 Reward: 0.27
# Distance 3.7 Color: [113 182 235], Target: [108 182 239], 5 Reward: 0.13
# Distance 4.08 Color: [113 182 234], Target: [108 182 239], 5 Reward: 0.13
# Distance 3.7 Color: [112 182 234], Target: [108 182 239], 1 Reward: 0.37
# Distance 3.37 Color: [111 182 234], Target: [108 182 239], 1 Reward: 0.38
# Distance 2.89 Color: [111 182 235], Target: [108 182 239], 4 Reward: 0.37
# Distance 2.58 Color: [110 182 235], Target: [108 182 239], 1 Reward: 0.41
# Distance 2.65 Color: [110 183 235], Target: [108 182 239], 2 Reward: -0.23
# Distance 2.45 Color: [109 183 235], Target: [108 182 239], 1 Reward: 0.1
# Distance 3.0 Color: [109 183 234], Target: [108 182 239], 5 Reward: -0.23
# Distance 3.16 Color: [109 184 234], Target: [108 182 239], 2 Reward: -0.23
# Distance 2.65 Color: [109 184 235], Target: [108 182 239], 4 Reward: 0.0
# Distance 2.45 Color: [109 183 235], Target: [108 182 239], 3 Reward: 0.1
# Distance 3.0 Color: [109 183 234], Target: [108 182 239], 5 Reward: -0.23
# Distance 2.45 Color: [109 183 235], Target: [108 182 239], 4 Reward: 0.0
# Distance 2.65 Color: [110 183 235], Target: [108 182 239], 0 Reward: -0.23
# Distance 2.58 Color: [110 182 235], Target: [108 182 239], 3 Reward: 0.27
# Distance 2.89 Color: [111 182 235], Target: [108 182 239], 0 Reward: 0.13
# Distance 2.45 Color: [111 182 236], Target: [108 182 239], 4 Reward: 0.38
# Distance 2.08 Color: [111 182 237], Target: [108 182 239], 4 Reward: 0.41
# Distance 2.16 Color: [111 183 237], Target: [108 182 239], 2 Reward: -0.23
# Distance 1.91 Color: [111 183 238], Target: [108 182 239], 4 Reward: 0.1
# Distance 2.16 Color: [111 183 237], Target: [108 182 239], 5 Reward: -0.23
# Distance 1.91 Color: [111 183 238], Target: [108 182 239], 4 Reward: 0.1
# Distance 2.45 Color: [112 183 238], Target: [108 182 239], 0 Reward: -0.23
# Distance 2.65 Color: [112 183 237], Target: [108 182 239], 5 Reward: -0.23
# Distance 2.58 Color: [112 182 237], Target: [108 182 239], 3 Reward: 0.27
# Distance 3.11 Color: [113 182 237], Target: [108 182 239], 0 Reward: 0.13
# Distance 2.58 Color: [112 182 237], Target: [108 182 239], 1 Reward: 0.37
# Distance 3.11 Color: [113 182 237], Target: [108 182 239], 0 Reward: 0.13
# Distance 3.65 Color: [114 182 237], Target: [108 182 239], 0 Reward: 0.13
# Distance 3.7 Color: [114 181 237], Target: [108 182 239], 3 Reward: -0.23
# Distance 3.16 Color: [113 181 237], Target: [108 182 239], 1 Reward: -0.01
# Distance 2.65 Color: [112 181 237], Target: [108 182 239], 1 Reward: 0.0
# Distance 3.16 Color: [113 181 237], Target: [108 182 239], 0 Reward: -0.23
# Distance 2.65 Color: [112 181 237], Target: [108 182 239], 1 Reward: 0.0
# Distance 2.45 Color: [112 181 238], Target: [108 182 239], 4 Reward: 0.1
# Distance 2.65 Color: [112 181 237], Target: [108 182 239], 5 Reward: -0.23
# Distance 2.83 Color: [112 180 237], Target: [108 182 239], 3 Reward: -0.23
# Distance 3.11 Color: [112 180 236], Target: [108 182 239], 5 Reward: -0.23
# Distance 3.56 Color: [113 180 236], Target: [108 182 239], 0 Reward: -0.23
# Distance 3.42 Color: [113 181 236], Target: [108 182 239], 2 Reward: 0.1
# Distance 3.56 Color: [113 180 236], Target: [108 182 239], 3 Reward: -0.23
# Distance 3.11 Color: [112 180 236], Target: [108 182 239], 1 Reward: 0.0
# Distance 2.71 Color: [111 180 236], Target: [108 182 239], 1 Reward: 0.02
# Distance 2.38 Color: [110 180 236], Target: [108 182 239], 1 Reward: 0.04
# Distance 2.71 Color: [110 179 236], Target: [108 182 239], 3 Reward: -0.23
# Distance 3.11 Color: [110 179 235], Target: [108 182 239], 5 Reward: -0.23
# Distance 3.56 Color: [110 179 234], Target: [108 182 239], 5 Reward: -0.23
# Distance 4.04 Color: [110 179 233], Target: [108 182 239], 5 Reward: -0.23
# Distance 4.24 Color: [111 179 233], Target: [108 182 239], 0 Reward: -0.23
# Distance 4.73 Color: [111 179 232], Target: [108 182 239], 5 Reward: -0.23
# Distance 4.24 Color: [111 179 233], Target: [108 182 239], 4 Reward: -0.02
# Distance 4.04 Color: [110 179 233], Target: [108 182 239], 1 Reward: 0.04
# Distance 4.24 Color: [111 179 233], Target: [108 182 239], 0 Reward: -0.23
# Distance 4.04 Color: [111 180 233], Target: [108 182 239], 2 Reward: 0.04
# Distance 4.32 Color: [112 180 233], Target: [108 182 239], 0 Reward: -0.23
# Distance 4.04 Color: [111 180 233], Target: [108 182 239], 1 Reward: 0.02
# Distance 3.92 Color: [111 181 233], Target: [108 182 239], 2 Reward: 0.1
# Distance 3.42 Color: [111 181 234], Target: [108 182 239], 4 Reward: -0.01
# Distance 3.92 Color: [111 181 233], Target: [108 182 239], 5 Reward: -0.23
# Distance 3.42 Color: [111 181 234], Target: [108 182 239], 4 Reward: -0.01
# Distance 3.92 Color: [111 181 233], Target: [108 182 239], 5 Reward: -0.23
# Distance 4.2 Color: [112 181 233], Target: [108 182 239], 0 Reward: -0.23
# Distance 3.92 Color: [111 181 233], Target: [108 182 239], 1 Reward: 0.02
# Distance 3.42 Color: [111 181 234], Target: [108 182 239], 4 Reward: -0.01
# Distance 3.16 Color: [110 181 234], Target: [108 182 239], 1 Reward: 0.04
# Distance 2.65 Color: [110 181 235], Target: [108 182 239], 4 Reward: 0.0
# Distance 3.16 Color: [110 181 234], Target: [108 182 239], 5 Reward: -0.23
# Distance 3.32 Color: [110 180 234], Target: [108 182 239], 3 Reward: -0.23
# Distance 3.16 Color: [110 181 234], Target: [108 182 239], 2 Reward: 0.1
# Distance 3.11 Color: [110 182 234], Target: [108 182 239], 2 Reward: 0.27
# Distance 2.58 Color: [110 182 235], Target: [108 182 239], 4 Reward: 0.37
# Distance 2.65 Color: [110 181 235], Target: [108 182 239], 3 Reward: -0.23
# Distance 2.58 Color: [110 182 235], Target: [108 182 239], 2 Reward: 0.27
# Distance 2.38 Color: [109 182 235], Target: [108 182 239], 1 Reward: 0.47
# Distance 2.31 Color: [108 182 235], Target: [108 182 239], 1 Reward: 0.63
# Distance 2.38 Color: [108 183 235], Target: [108 182 239], 2 Reward: 0.13
# Distance 1.83 Color: [108 183 236], Target: [108 182 239], 4 Reward: 0.38
# Distance 1.91 Color: [109 183 236], Target: [108 182 239], 0 Reward: -0.23
# Distance 2.16 Color: [109 184 236], Target: [108 182 239], 2 Reward: -0.23
# Distance 2.65 Color: [109 184 235], Target: [108 182 239], 5 Reward: -0.23
# Distance 3.16 Color: [109 184 234], Target: [108 182 239], 5 Reward: -0.23
# Distance 3.0 Color: [109 183 234], Target: [108 182 239], 3 Reward: 0.1
# Distance 2.94 Color: [109 182 234], Target: [108 182 239], 3 Reward: 0.27
# Distance 3.0 Color: [109 181 234], Target: [108 182 239], 3 Reward: -0.23
# Distance 2.94 Color: [109 182 234], Target: [108 182 239], 2 Reward: 0.27
# Distance 2.89 Color: [108 182 234], Target: [108 182 239], 1 Reward: 0.63
# Distance 2.94 Color: [108 181 234], Target: [108 182 239], 3 Reward: 0.13
# Distance 2.38 Color: [108 181 235], Target: [108 182 239], 4 Reward: 0.37
# Distance 2.94 Color: [108 181 234], Target: [108 182 239], 5 Reward: 0.13
# Distance 2.89 Color: [108 182 234], Target: [108 182 239], 2 Reward: 0.63
# Distance 2.94 Color: [108 181 234], Target: [108 182 239], 3 Reward: 0.13
# Distance 3.0 Color: [107 181 234], Target: [108 182 239], 1 Reward: -0.23
# Distance 3.56 Color: [107 181 233], Target: [108 182 239], 5 Reward: -0.23
# Distance 4.12 Color: [107 181 232], Target: [108 182 239], 5 Reward: -0.23
# Distance 4.08 Color: [107 182 232], Target: [108 182 239], 2 Reward: 0.27
# Distance 4.12 Color: [107 183 232], Target: [108 182 239], 2 Reward: -0.23
# Distance 4.69 Color: [107 183 231], Target: [108 182 239], 5 Reward: -0.23
# Distance 4.8 Color: [106 183 231], Target: [108 182 239], 1 Reward: -0.23
# Distance 4.24 Color: [106 183 232], Target: [108 182 239], 4 Reward: -0.03
# Distance 4.8 Color: [106 183 231], Target: [108 182 239], 5 Reward: -0.23
# Distance 5.35 Color: [106 183 230], Target: [108 182 239], 5 Reward: -0.23
# Distance 5.26 Color: [107 183 230], Target: [108 182 239], 0 Reward: 0.1
# Distance 5.35 Color: [106 183 230], Target: [108 182 239], 1 Reward: -0.23
# Distance 5.92 Color: [106 183 229], Target: [108 182 239], 5 Reward: -0.23
# Distance 6.0 Color: [106 184 229], Target: [108 182 239], 2 Reward: -0.23
# Distance 5.92 Color: [107 184 229], Target: [108 182 239], 0 Reward: 0.1
# Distance 6.48 Color: [107 184 228], Target: [108 182 239], 5 Reward: -0.23
# Distance 5.92 Color: [107 184 229], Target: [108 182 239], 4 Reward: -0.04
# Distance 6.06 Color: [107 185 229], Target: [108 182 239], 2 Reward: -0.23
# Distance 6.61 Color: [107 185 228], Target: [108 182 239], 5 Reward: -0.23
# Distance 6.48 Color: [107 184 228], Target: [108 182 239], 3 Reward: 0.04
# Distance 6.56 Color: [106 184 228], Target: [108 182 239], 1 Reward: -0.23
# Distance 6.0 Color: [106 184 229], Target: [108 182 239], 4 Reward: -0.04
# Distance 5.92 Color: [107 184 229], Target: [108 182 239], 0 Reward: 0.1
# Distance 6.06 Color: [107 185 229], Target: [108 182 239], 2 Reward: -0.23
# Distance 6.61 Color: [107 185 228], Target: [108 182 239], 5 Reward: -0.23
# Distance 6.48 Color: [107 184 228], Target: [108 182 239], 3 Reward: 0.04
# Distance 5.92 Color: [107 184 229], Target: [108 182 239], 4 Reward: -0.04
# Distance 5.89 Color: [108 184 229], Target: [108 182 239], 0 Reward: 0.27
# Distance 5.8 Color: [108 183 229], Target: [108 182 239], 3 Reward: 0.47
# Distance 5.89 Color: [108 184 229], Target: [108 182 239], 2 Reward: 0.13
# Distance 5.8 Color: [108 183 229], Target: [108 182 239], 3 Reward: 0.47
# Distance 5.83 Color: [107 183 229], Target: [108 182 239], 1 Reward: -0.23
# Distance 5.26 Color: [107 183 230], Target: [108 182 239], 4 Reward: -0.03
# Distance 5.23 Color: [108 183 230], Target: [108 182 239], 0 Reward: 0.27
# Distance 5.2 Color: [108 182 230], Target: [108 182 239], 3 Reward: 0.63
# Distance 5.77 Color: [108 182 229], Target: [108 182 239], 5 Reward: 0.5
# Distance 6.35 Color: [108 182 228], Target: [108 182 239], 5 Reward: 0.5
# Distance 6.38 Color: [108 181 228], Target: [108 182 239], 3 Reward: 0.13
# Distance 6.4 Color: [107 181 228], Target: [108 182 239], 1 Reward: -0.23
# Distance 6.48 Color: [107 180 228], Target: [108 182 239], 3 Reward: -0.23
# Distance 6.45 Color: [108 180 228], Target: [108 182 239], 0 Reward: 0.27
# Distance 6.48 Color: [109 180 228], Target: [108 182 239], 0 Reward: -0.23
# Distance 6.61 Color: [109 179 228], Target: [108 182 239], 3 Reward: -0.23
# Distance 6.68 Color: [110 179 228], Target: [108 182 239], 0 Reward: -0.23
# Distance 6.14 Color: [110 179 229], Target: [108 182 239], 4 Reward: -0.04
# Distance 5.6 Color: [110 179 230], Target: [108 182 239], 4 Reward: -0.03
# Distance 5.8 Color: [110 178 230], Target: [108 182 239], 3 Reward: -0.23
# Distance 6.32 Color: [110 178 229], Target: [108 182 239], 5 Reward: -0.23
# Distance 6.45 Color: [111 178 229], Target: [108 182 239], 0 Reward: -0.23
# Distance 6.27 Color: [111 179 229], Target: [108 182 239], 2 Reward: 0.02
# Distance 6.14 Color: [111 180 229], Target: [108 182 239], 2 Reward: 0.04
# Distance 5.6 Color: [111 180 230], Target: [108 182 239], 4 Reward: -0.03
# Distance 5.07 Color: [111 180 231], Target: [108 182 239], 4 Reward: -0.03
# Distance 4.55 Color: [111 180 232], Target: [108 182 239], 4 Reward: -0.03
# Distance 4.43 Color: [111 181 232], Target: [108 182 239], 2 Reward: 0.1
# Distance 4.24 Color: [110 181 232], Target: [108 182 239], 1 Reward: 0.04
# Distance 4.43 Color: [111 181 232], Target: [108 182 239], 0 Reward: -0.23
# Distance 4.55 Color: [111 180 232], Target: [108 182 239], 3 Reward: -0.23
# Distance 4.36 Color: [110 180 232], Target: [108 182 239], 1 Reward: 0.04
# Distance 4.9 Color: [110 180 231], Target: [108 182 239], 5 Reward: -0.23
# Distance 4.36 Color: [110 180 232], Target: [108 182 239], 4 Reward: -0.03
# Distance 4.9 Color: [110 180 231], Target: [108 182 239], 5 Reward: -0.23
# Distance 5.45 Color: [110 180 230], Target: [108 182 239], 5 Reward: -0.23
# Distance 5.6 Color: [110 179 230], Target: [108 182 239], 3 Reward: -0.23
# Distance 5.8 Color: [110 178 230], Target: [108 182 239], 3 Reward: -0.23
# Distance 6.32 Color: [110 178 229], Target: [108 182 239], 5 Reward: -0.23
# Distance 5.8 Color: [110 178 230], Target: [108 182 239], 4 Reward: -0.03
# Distance 5.94 Color: [111 178 230], Target: [108 182 239], 0 Reward: -0.23
# Distance 6.19 Color: [111 177 230], Target: [108 182 239], 3 Reward: -0.23
# Distance 5.72 Color: [111 177 231], Target: [108 182 239], 4 Reward: -0.03
# Distance 5.45 Color: [111 178 231], Target: [108 182 239], 2 Reward: 0.0
# Distance 5.29 Color: [110 178 231], Target: [108 182 239], 1 Reward: 0.04
# Distance 5.07 Color: [110 179 231], Target: [108 182 239], 2 Reward: 0.02
# Distance 5.23 Color: [111 179 231], Target: [108 182 239], 0 Reward: -0.23
# Distance 5.07 Color: [111 180 231], Target: [108 182 239], 2 Reward: 0.04
# Distance 4.55 Color: [111 180 232], Target: [108 182 239], 4 Reward: -0.03
# Distance 4.43 Color: [111 181 232], Target: [108 182 239], 2 Reward: 0.1
# Distance 4.69 Color: [112 181 232], Target: [108 182 239], 0 Reward: -0.23
# Distance 5.0 Color: [113 181 232], Target: [108 182 239], 0 Reward: -0.23
# Distance 4.97 Color: [113 182 232], Target: [108 182 239], 2 Reward: 0.27
# Distance 5.0 Color: [113 181 232], Target: [108 182 239], 3 Reward: -0.23
# Distance 4.55 Color: [113 181 233], Target: [108 182 239], 4 Reward: -0.02
# Distance 4.93 Color: [114 181 233], Target: [108 182 239], 0 Reward: -0.23
# Distance 5.03 Color: [114 180 233], Target: [108 182 239], 3 Reward: -0.23
# Distance 5.45 Color: [115 180 233], Target: [108 182 239], 0 Reward: -0.23
# Distance 5.89 Color: [116 180 233], Target: [108 182 239], 0 Reward: -0.23
# Distance 5.57 Color: [116 180 234], Target: [108 182 239], 4 Reward: -0.01
# Distance 6.06 Color: [117 180 234], Target: [108 182 239], 0 Reward: -0.23
# Distance 5.8 Color: [117 180 235], Target: [108 182 239], 4 Reward: 0.0
# Distance 5.72 Color: [117 181 235], Target: [108 182 239], 2 Reward: 0.1
# Distance 5.97 Color: [117 181 234], Target: [108 182 239], 5 Reward: -0.23
# Distance 5.48 Color: [116 181 234], Target: [108 182 239], 1 Reward: -0.03
# Distance 5.45 Color: [116 182 234], Target: [108 182 239], 2 Reward: 0.27
# Distance 5.48 Color: [116 183 234], Target: [108 182 239], 2 Reward: -0.23
# Distance 5.57 Color: [116 184 234], Target: [108 182 239], 2 Reward: -0.23
# Distance 5.48 Color: [116 183 234], Target: [108 182 239], 3 Reward: 0.1
# Distance 5.45 Color: [116 182 234], Target: [108 182 239], 3 Reward: 0.27
# Distance 5.94 Color: [117 182 234], Target: [108 182 239], 0 Reward: 0.13
# Distance 6.45 Color: [118 182 234], Target: [108 182 239], 0 Reward: 0.13
# Distance 5.94 Color: [117 182 234], Target: [108 182 239], 1 Reward: 0.33
# Distance 5.97 Color: [117 183 234], Target: [108 182 239], 2 Reward: -0.23
# Distance 6.48 Color: [118 183 234], Target: [108 182 239], 0 Reward: -0.23
# Distance 6.24 Color: [118 183 235], Target: [108 182 239], 4 Reward: 0.0
# Distance 6.48 Color: [118 183 234], Target: [108 182 239], 5 Reward: -0.23
# Distance 5.97 Color: [117 183 234], Target: [108 182 239], 1 Reward: -0.03
# Distance 5.94 Color: [117 182 234], Target: [108 182 239], 3 Reward: 0.27
# Distance 5.45 Color: [116 182 234], Target: [108 182 239], 1 Reward: 0.34
# Distance 4.97 Color: [115 182 234], Target: [108 182 239], 1 Reward: 0.34
# Distance 4.65 Color: [115 182 235], Target: [108 182 239], 4 Reward: 0.37
# Distance 4.16 Color: [114 182 235], Target: [108 182 239], 1 Reward: 0.35
# Distance 3.7 Color: [113 182 235], Target: [108 182 239], 1 Reward: 0.36
# Distance 3.37 Color: [113 182 236], Target: [108 182 239], 4 Reward: 0.38
# Distance 3.7 Color: [113 182 235], Target: [108 182 239], 5 Reward: 0.13
# Distance 3.37 Color: [113 182 236], Target: [108 182 239], 4 Reward: 0.38
# Distance 2.89 Color: [112 182 236], Target: [108 182 239], 1 Reward: 0.37
# Distance 2.45 Color: [111 182 236], Target: [108 182 239], 1 Reward: 0.38
# Distance 2.08 Color: [111 182 237], Target: [108 182 239], 4 Reward: 0.41
# Distance 1.83 Color: [111 182 238], Target: [108 182 239], 4 Reward: 0.47
# Distance 1.29 Color: [110 182 238], Target: [108 182 239], 1 Reward: 0.41
# Distance 0.82 Color: [109 182 238], Target: [108 182 239], 1 Reward: 0.47
# Distance 0.58 Color: [109 182 239], Target: [108 182 239], 4 Reward: 0.63
# Distance 0.0 Color: [108 182 239], Target: [108 182 239], 1 Reward: 1.0
# Done in 872 steps

# %%
model.save('./palette_lin')

# %%
™
